# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
from scipy.optimize import minimize
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Proyecto de Optimización Numérica I
#
# - Samuel Elí Méndez Sánchez 196659
# - Santiago Casanova Díaz 189756
# - Eduardo Mateo Guajardo Rodriguez 166273
# - Sebastian Ibarra Del Corral 193992
# - Sandra Reyes Benavides 179149

# %%
iris = pd.read_csv("Iris.csv")
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
n = 149
x = iris["SepalLengthCm"]
y = iris["SepalWidthCm"]
z = iris["PetalLengthCm"]
c = iris["PetalWidthCm"]
species = iris["Species"]

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

scatter = ax.scatter(x, y, z, c=c, cmap='viridis')

plt.colorbar(scatter, label='PetalWidthCm')

ax.set_xlabel('SepalLengthCm')
ax.set_ylabel('SepalWidthCm')
ax.set_zlabel('PetalLenghtCm')

plt.title("Iris dataset", loc='center')

for i in range(n):
    if(np.random.rand()<0.1):
        ax.text(x[i], y[i], z[i], species[i], color='black', fontsize=8)

plt.show()

# %%
#Separamos primero los conjuntos: 
A = iris[iris["Species"]=="Iris-setosa"]
B = iris[iris["Species"]=="Iris-virginica"]
C = iris[iris["Species"]=="Iris-versicolor"]

# %%
A_mat = A[["SepalLengthCm", "SepalWidthCm", "PetalLengthCm", "PetalWidthCm"]].values
B_mat = B[["SepalLengthCm", "SepalWidthCm", "PetalLengthCm", "PetalWidthCm"]].values
C_mat = C[["SepalLengthCm", "SepalWidthCm", "PetalLengthCm", "PetalWidthCm"]].values
Vec_m1= np.full((50, 1), -1)
Vec_1 = np.full((50, 1), 1)

d = np.full((100, 1), 1)
c = np.full((5,1),0)

# %% [markdown]
# ### A vs B
#
# Minimizar $\frac{1}{2} w^T w$ sujeto a:
#
#
# \begin{cases}
# w^T x_i + \beta \leq -1, & \text{para } i = 1, 2, \ldots, s \\
# w^T x_i + \beta \geq 1, & \text{para } i = s + 1, s + 2, \ldots, s + r
# \end{cases}
#
#
# Donde:
#
# $w$ es un vector de variables de optimización.
# $\beta$ es una constante.
# $x_i$ son vectores de datos.
# $s$ y $r$ son números enteros.
#
# Vemos que para obtener la matriz F solamente hacemos un par de operaciones algebraicas:
#
# La matriz F debe quedar de la forma:
#
# \begin{bmatrix}
# [-\text{transposed}(x_i)] & [-1] \\
# [\text{transposed}(x_i)] & [1] \\
# \end{bmatrix}
#
# \begin{bmatrix}
# [-A_{mat}] & [Vec_{m1}] \\
# [B] & [Vec_1] \\
# \end{bmatrix}

# %%
concatenated_matrix_up = np.hstack((-A_mat, Vec_m1))
concatenated_matrix_down = np.hstack((B_mat, Vec_1))
final_matrix = np.vstack((concatenated_matrix_up,concatenated_matrix_down))
F = final_matrix

# %%
Q=np.diag([1,1,1,1,1])
F=final_matrix
print(Q.shape)
print(F.shape)
print(d.shape)
print(c.shape)
# Out:
# (5, 5)
# (100, 5)
# (100, 1)
# (5, 1)

# %%
def paso_intpoint(u, v):
    p = len(u)
    v_alfa = np.ones(p)
    for i in range(p):
         if v[i] < 0:
             v_alfa[i] = -u[i] / v[i]
    alfa = min(np.amin(v_alfa), 1.0)        
    return alfa

# %%
def myqp_intpoint_modificado(Q, F, c, d):
    n = len(c)
    p = len(d)
    tol = 10**(-5)
    maxiter = 100
    iter = 0
    x = np.ones((n, 1)) # Asegúrate de que x es un vector columna
    mu = np.ones((p, 1)) # Asegúrate de que mu es un vector columna
    z = np.ones((p, 1)) # Asegúrate de que z es un vector columna
    
    while iter < maxiter:
        iter += 1
        # Calcula los componentes de cnpo para esta iteración
        v1 = np.dot(Q, x) - np.dot(F.T, mu) + c
        v3 = -np.dot(F, x) + z + d
        v4 = mu * z # Multiplicación elemento a elemento

        # Usa np.vstack para concatenar verticalmente y formar cnpo correctamente
        cnpo = np.vstack([v1, v3, v4])
        norma_cnpo = np.linalg.norm(cnpo)
        
        if norma_cnpo <= tol:
            break
        
        # Ajustes para preparar la solución del sistema lineal
        M = np.zeros((n + 2*p, n + 2*p))
        M[:n, :n] = Q
        M[:n, n:n+p] = -F.T
        M[n:n+p, :n] = -F
        M[n:n+p, n+p:] = np.eye(p)
        M[n+p:, n:n+p] = np.diagflat(z)
        M[n+p:, n+p:] = np.diagflat(mu)

        # Ajuste el lado derecho del sistema
        cnpo_pert = cnpo.copy()
        cnpo_pert[n+p:] -= 0.5 / p * np.sum(mu * z)
        
        # Resuelve el sistema lineal
        dw = np.linalg.solve(M, -cnpo_pert)
        dx = dw[:n]
        dmu = dw[n:n+p]
        dz = dw[n+p:]

        # Calcula los pasos para mu y z
        alfa1 = paso_intpoint(mu.flatten(), dmu.flatten())
        alfa2 = paso_intpoint(z.flatten(), dz.flatten())
        alfa = 0.95 * min(alfa1, alfa2, 1.0)

        # Actualiza las variables
        x += alfa * dx
        mu += alfa * dmu
        z += alfa * dz

        print("Iteración:", iter, "| Norma de cnpo:", norma_cnpo)

    return x, mu, z, iter

# Nota: Asegúrate de definir Q, F, c, y d antes de llamar a esta función.

# %%
(x,mu,z,iter)=myqp_intpoint_modificado(Q, F, c, d)
# Out:
# Iteración: 1 | Norma de cnpo: 278.664098871742
# Iteración: 2 | Norma de cnpo: 153.13958951041593
# Iteración: 3 | Norma de cnpo: 27.07693486382677
# Iteración: 4 | Norma de cnpo: 7.085835078635453
# Iteración: 5 | Norma de cnpo: 0.4756906118642916
# Iteración: 6 | Norma de cnpo: 0.1852036245770674
# Iteración: 7 | Norma de cnpo: 0.10661031962806933
# Iteración: 8 | Norma de cnpo: 0.06143395962386648
# Iteración: 9 | Norma de cnpo: 0.03517015773273118
# Iteración: 10 | Norma de cnpo: 0.021505344413722427
# Iteración: 11 | Norma de cnpo: 0.012052610920527345
# Iteración: 12 | Norma de cnpo: 0.007889995772773594
# Iteración: 13 | Norma de cnpo: 0.004305342886292943
# Iteración: 14 | Norma de cnpo: 0.002801973404499096
# Iteración: 15 | Norma de cnpo: 0.0014707940705647373
# Iteración: 16 | Norma de cnpo: 0.00077560026579501
# Iteración: 17 | Norma de cnpo: 0.00040838360424471455
# Iteración: 18 | Norma de cnpo: 0.0002148429382307443
# Iteración: 19 | Norma de cnpo: 0.00011292194335415046
# Iteración: 20 | Norma de cnpo: 5.9320818146702826e-05
# Iteración: 21 | Norma de cnpo: 3.115372180983635e-05
# Iteración: 22 | Norma de cnpo: 1.6358560573168452e-05

# %%
x
# Out:
# array([[-0.26728515],
#        [-0.23013789],
#        [ 0.60545728],
#        [ 0.30023956],
#        [-0.14506836]])

# %% [markdown]
# #### Grafica con todas las dimensiones

# %%
w = x[:-1]  
beta = x[-1] 
A = A_mat
B = B_mat

# Calcula ATw - e y BTw - e
e = np.ones(A.shape[0])
ATw_minus_e = A.dot(w) - e * beta

e = np.ones(B.shape[0])
BTw_minus_e = B.dot(w) - e * beta

# Graficación
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.plot(ATw_minus_e, label='ATw - e')
plt.title('Conjunto A')
plt.xlabel('Índice del Punto')
plt.ylabel('Valor')
#plt.legend()

plt.subplot(1, 2, 2)
plt.plot(BTw_minus_e, label='BTw - e')
plt.title('Conjunto B')
plt.xlabel('Índice del Punto')
plt.ylabel('Valor')
#plt.legend()

plt.tight_layout()
plt.show()

# %%
# Asumiendo que w, beta, A_mat, y B_mat están definidos
w = x[:-1]  # vector w
beta = x[-1]  # valor beta
A = A_mat  # matriz A
B = B_mat  # matriz B

# Calcula ATw - e y BTw - e
e_A = np.ones(A.shape[0])
ATw_minus_e = A.dot(w) - e_A * beta

e_B = np.ones(B.shape[0])
BTw_minus_e = B.dot(w) - e_B * beta

# Asegurémonos de que las dimensiones de ATw_minus_e y BTw_minus_e son adecuadas para graficar
# Por claridad, vamos a aplanar los arrays para garantizar que son 1D
ATw_minus_e = ATw_minus_e.flatten()
BTw_minus_e = BTw_minus_e.flatten()

# Graficación en una sola gráfica usando scatter
plt.figure(figsize=(10, 5))

# Aquí no necesitamos generar índices ya que scatter puede manejar los valores directamente
plt.scatter(np.arange(len(ATw_minus_e)), ATw_minus_e, color='blue', label='Conjunto A', alpha=0.7)
plt.scatter(np.arange(len(BTw_minus_e)) + len(ATw_minus_e), BTw_minus_e, color='red', label='Conjunto B', alpha=0.7)

plt.title('Comparación de Conjunto A y B respecto al Hiperplano')
plt.xlabel('Índice del Punto')
plt.ylabel('Valor (ATw - e, BTw - e)')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Visualización del conjunto

# %%
A = A_mat
B = B_mat

w = x[:-1]  
beta = x[-1] 


# Definir las combinaciones de características
combinaciones = [(0, 1), (0, 2), (0, 3), (1, 2), (1, 3), (2, 3)]

# Crear una figura y ejes para las subgráficas
fig, axes = plt.subplots(2, 3, figsize=(15, 10))
fig.suptitle('Comparación de Grupos A y B en diferentes combinaciones de características')

for i, (feat1, feat2) in enumerate(combinaciones):
    ax = axes[i//3, i%3]
    # Graficar los puntos de A y B para cada combinación de características
    ax.scatter(A[:, feat1], A[:, feat2], color='blue', label='Grupo A')
    ax.scatter(B[:, feat1], B[:, feat2], color='red', label='Grupo B')
    ax.set_xlabel(f'Característica {feat1+1}')
    ax.set_ylabel(f'Característica {feat2+1}')
    ax.legend()


plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %% [markdown]
# # Para el caso de Virginica con Versicolor
# ### A vs C

# %%
concatenated_matrix_up = np.hstack((-A_mat, Vec_m1))
concatenated_matrix_down = np.hstack((C_mat, Vec_1))
final_matrix = np.vstack((concatenated_matrix_up,concatenated_matrix_down))
F2 = final_matrix

# %%
(x,mu,z,iter)= myqp_intpoint_modificado(Q, F2, c, d)
# Out:
# Iteración: 1 | Norma de cnpo: 207.2205588256146
# Iteración: 2 | Norma de cnpo: 118.81354937857414
# Iteración: 3 | Norma de cnpo: 24.797009163425578
# Iteración: 4 | Norma de cnpo: 5.898760288291389
# Iteración: 5 | Norma de cnpo: 0.5194603159629674
# Iteración: 6 | Norma de cnpo: 0.24932559125261575
# Iteración: 7 | Norma de cnpo: 0.14335068703438997
# Iteración: 8 | Norma de cnpo: 0.08876356182863841
# Iteración: 9 | Norma de cnpo: 0.06878163948769217
# Iteración: 10 | Norma de cnpo: 0.038324999518168944
# Iteración: 11 | Norma de cnpo: 0.022546220509598768
# Iteración: 12 | Norma de cnpo: 0.012796091009465046
# Iteración: 13 | Norma de cnpo: 0.006754934716841806
# Iteración: 14 | Norma de cnpo: 0.003562459407399881
# Iteración: 15 | Norma de cnpo: 0.0018740356490767435
# Iteración: 16 | Norma de cnpo: 0.0009851579520075227
# Iteración: 17 | Norma de cnpo: 0.0005175692447177817
# Iteración: 18 | Norma de cnpo: 0.000271824727585601
# Iteración: 19 | Norma de cnpo: 0.00014273597573087244
# Iteración: 20 | Norma de cnpo: 7.494413085079817e-05
# Iteración: 21 | Norma de cnpo: 3.9347807071026005e-05
# Iteración: 22 | Norma de cnpo: 2.0658188689050012e-05
# Iteración: 23 | Norma de cnpo: 1.0845711759221933e-05

# %%
x
# Out:
# array([[-0.3094533 ],
#        [-0.42972132],
#        [ 1.0455132 ],
#        [ 0.61780655],
#        [-0.16361098]])

# %% [markdown]
# #### Grafica con todas las dimensiones

# %%
w = x[:-1]  
beta = x[-1] 
A = A_mat
B = C_mat

# Calcula ATw - e y BTw - e
e = np.ones(A.shape[0])
ATw_minus_e = A.dot(w) - e * beta

e = np.ones(B.shape[0])
BTw_minus_e = B.dot(w) - e * beta

# Graficación
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.plot(ATw_minus_e, label='ATw - e')
plt.title('Conjunto A')
plt.xlabel('Índice del Punto')
plt.ylabel('Valor')
#plt.legend()

plt.subplot(1, 2, 2)
plt.plot(BTw_minus_e, label='BTw - e')
plt.title('Conjunto C')
plt.xlabel('Índice del Punto')
plt.ylabel('Valor')
#plt.legend()

plt.tight_layout()
plt.show()

# %%
w = x[:-1]  
beta = x[-1] 
A = A_mat
B = C_mat

# Calcula ATw - e y BTw - e
e_A = np.ones(A.shape[0])
ATw_minus_e = A.dot(w) - e_A * beta

e_B = np.ones(B.shape[0])
BTw_minus_e = B.dot(w) - e_B * beta

# Asegurémonos de que las dimensiones de ATw_minus_e y BTw_minus_e son adecuadas para graficar
# Por claridad, vamos a aplanar los arrays para garantizar que son 1D
ATw_minus_e = ATw_minus_e.flatten()
BTw_minus_e = BTw_minus_e.flatten()

# Graficación en una sola gráfica usando scatter
plt.figure(figsize=(10, 5))

# Aquí no necesitamos generar índices ya que scatter puede manejar los valores directamente
plt.scatter(np.arange(len(ATw_minus_e)), ATw_minus_e, color='blue', label='Conjunto A', alpha=0.7)
plt.scatter(np.arange(len(BTw_minus_e)) + len(ATw_minus_e), BTw_minus_e, color='red', label='Conjunto C', alpha=0.7)

plt.title('Comparación de Conjunto A y C respecto al Hiperplano')
plt.xlabel('Índice del Punto')
plt.ylabel('Valor (ATw - e, CTw - e)')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Visualización del conjunto

# %%
A = A_mat
B = C_mat

w = x[:-1]  
beta = x[-1] 


# Definir las combinaciones de características
combinaciones = [(0, 1), (0, 2), (0, 3), (1, 2), (1, 3), (2, 3)]

# Crear una figura y ejes para las subgráficas
fig, axes = plt.subplots(2, 3, figsize=(15, 10))
fig.suptitle('Comparación de Grupos A y C en diferentes combinaciones de características')

for i, (feat1, feat2) in enumerate(combinaciones):
    ax = axes[i//3, i%3]
    # Graficar los puntos de A y B para cada combinación de características
    ax.scatter(A[:, feat1], A[:, feat2], color='blue', label='Grupo A')
    ax.scatter(B[:, feat1], B[:, feat2], color='red', label='Grupo C')
    ax.set_xlabel(f'Característica {feat1+1}')
    ax.set_ylabel(f'Característica {feat2+1}')
    ax.legend()


plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %% [markdown]
# # Para el caso de Versicolor con Virgilia
# ### B vs C

# %%
concatenated_matrix_up = np.hstack((-B_mat, Vec_m1))
concatenated_matrix_down = np.hstack((C_mat, Vec_1))
final_matrix = np.vstack((concatenated_matrix_up,concatenated_matrix_down))
F3 = final_matrix

# %%
(x,mu,z,iter)= myqp_intpoint_modificado(Q, F3, c, d)
# Out:
# Iteración: 1 | Norma de cnpo: 190.40735279920258
# Iteración: 2 | Norma de cnpo: 133.52234816082142
# Iteración: 3 | Norma de cnpo: 122.76194107043496
# Iteración: 4 | Norma de cnpo: 115.51459068778787
# Iteración: 5 | Norma de cnpo: 110.65165637240267
# Iteración: 6 | Norma de cnpo: 109.32466396882528
# Iteración: 7 | Norma de cnpo: 103.41406094483564
# Iteración: 8 | Norma de cnpo: 101.44314844373677
# Iteración: 9 | Norma de cnpo: 101.07907541993943
# Iteración: 10 | Norma de cnpo: 100.14048825748799
# Iteración: 11 | Norma de cnpo: 98.55572773026766
# Iteración: 12 | Norma de cnpo: 97.71134653492531
# Iteración: 13 | Norma de cnpo: 95.7713050460225
# Iteración: 14 | Norma de cnpo: 95.20028689672154
# Iteración: 15 | Norma de cnpo: 95.08800684942946
# Iteración: 16 | Norma de cnpo: 95.07386885294588
# Iteración: 17 | Norma de cnpo: 95.07241724356689
# Iteración: 18 | Norma de cnpo: 95.07229702815748
# Iteración: 19 | Norma de cnpo: 95.0722888060914
# Iteración: 20 | Norma de cnpo: 95.07228831586033
# Iteración: 21 | Norma de cnpo: 95.07228828962118
# Iteración: 22 | Norma de cnpo: 95.07228828814445
# Iteración: 23 | Norma de cnpo: 95.0722882878774
# Iteración: 24 | Norma de cnpo: 95.07228828793728
# Iteración: 25 | Norma de cnpo: 95.0722882878606
# Iteración: 26 | Norma de cnpo: 95.07228828803119
# Iteración: 27 | Norma de cnpo: 95.07228828761721
# Iteración: 28 | Norma de cnpo: 95.07228828787653
# Iteración: 29 | Norma de cnpo: 95.0722882879005
# Iteración: 30 | Norma de cnpo: 95.07228828793528
# Iteración: 31 | Norma de cnpo: 95.07228828782095
# Iteración: 32 | Norma de cnpo: 95.07228828775006
# Iteración: 33 | Norma de cnpo: 95.07228828758018
# Iteración: 34 | Norma de cnpo: 95.07228828745065
# Iteración: 35 | Norma de cnpo: 95.07228828758554
# Iteración: 36 | Norma de cnpo: 95.07228828753969
# Iteración: 37 | Norma de cnpo: 95.07228828765587
# Iteración: 38 | Norma de cnpo: 95.07228828744437
# Iteración: 39 | Norma de cnpo: 95.07228828766341
# Iteración: 40 | Norma de cnpo: 95.07228828750296
# Iteración: 41 | Norma de cnpo: 95.0722882876309
# Iteración: 42 | Norma de cnpo: 95.0722882877828
# Iteración: 43 | Norma de cnpo: 95.07228828775851
# Iteración: 44 | Norma de cnpo: 95.07228828783376
# Iteración: 45 | Norma de cnpo: 95.07228828775158
# Iteración: 46 | Norma de cnpo: 95.07228828759936
# Iteración: 47 | Norma de cnpo: 95.07228828765446
# Iteración: 48 | Norma de cnpo: 95.07228828761527
# Iteración: 49 | Norma de cnpo: 95.07228828766799
# Iteración: 50 | Norma de cnpo: 95.07228828787387
# Iteración: 51 | Norma de cnpo: 95.07228828769769
# Iteración: 52 | Norma de cnpo: 95.0722882878168
# Iteración: 53 | Norma de cnpo: 95.07228828767838
# Iteración: 54 | Norma de cnpo: 95.07228828774718
# Iteración: 55 | Norma de cnpo: 95.07228828764067
# Iteración: 56 | Norma de cnpo: 95.07228828760469
# Iteración: 57 | Norma de cnpo: 95.07228828752673
# Iteración: 58 | Norma de cnpo: 95.07228828742305
# Iteración: 59 | Norma de cnpo: 95.072288287447
# Iteración: 60 | Norma de cnpo: 95.07228828719536
# Iteración: 61 | Norma de cnpo: 95.07228828726538
# Iteración: 62 | Norma de cnpo: 95.07228828726329
# Iteración: 63 | Norma de cnpo: 95.07228828716383
# Iteración: 64 | Norma de cnpo: 95.07228828707754
# Iteración: 65 | Norma de cnpo: 95.0722882870824
# Iteración: 66 | Norma de cnpo: 95.07228828731539
# Iteración: 67 | Norma de cnpo: 95.07228828726568
# Iteración: 68 | Norma de cnpo: 95.07228828729514
# Iteración: 69 | Norma de cnpo: 95.0722882870481
# Iteración: 70 | Norma de cnpo: 95.07228828734308
# Iteración: 71 | Norma de cnpo: 95.07228828734723
# Iteración: 72 | Norma de cnpo: 95.07228828735889
# Iteración: 73 | Norma de cnpo: 95.07228828724277
# Iteración: 74 | Norma de cnpo: 95.07228828737794
# Iteración: 75 | Norma de cnpo: 95.072288287295
# Iteración: 76 | Norma de cnpo: 95.07228828741553
# Iteración: 77 | Norma de cnpo: 95.07228828750677
# Iteración: 78 | Norma de cnpo: 95.07228828741867
# Iteración: 79 | Norma de cnpo: 95.07228828753755
# Iteración: 80 | Norma de cnpo: 95.07228828740668
# Iteración: 81 | Norma de cnpo: 95.07228828732019
# Iteración: 82 | Norma de cnpo: 95.0722882873806
# Iteración: 83 | Norma de cnpo: 95.07228828730746
# Iteración: 84 | Norma de cnpo: 95.0722882873806
# Iteración: 85 | Norma de cnpo: 95.07228828727426
# Iteración: 86 | Norma de cnpo: 95.0722882873806
# Iteración: 87 | Norma de cnpo: 95.07228828726696
# Iteración: 88 | Norma de cnpo: 95.0722882871499
# Iteración: 89 | Norma de cnpo: 95.07228828734054
# Iteración: 90 | Norma de cnpo: 95.07228828723024
# Iteración: 91 | Norma de cnpo: 95.07228828735596
# Iteración: 92 | Norma de cnpo: 95.07228828724051
# Iteración: 93 | Norma de cnpo: 95.07228828711828
# Iteración: 94 | Norma de cnpo: 95.07228828728167
# Iteración: 95 | Norma de cnpo: 95.0722882871285
# Iteración: 96 | Norma de cnpo: 95.07228828728167
# Iteración: 97 | Norma de cnpo: 95.07228828711554
# Iteración: 98 | Norma de cnpo: 95.07228828728167
# Iteración: 99 | Norma de cnpo: 95.07228828708337
# Iteración: 100 | Norma de cnpo: 95.07228828728167

# %%
x
# Out:
# array([[0.5],
#        [0.5],
#        [0.5],
#        [0.5],
#        [0.5]])

# %% [markdown]
# #### Grafica con todas las dimensiones

# %%
w = x[:-1]  
beta = x[-1] 
A = C_mat
B = A_mat

# Calcula ATw - e y BTw - e
e = np.ones(A.shape[0])
ATw_minus_e = A.dot(w) - e * beta

e = np.ones(B.shape[0])
BTw_minus_e = B.dot(w) - e * beta

# Graficación
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.plot(ATw_minus_e, label='ATw - e')
plt.title('Conjunto B')
plt.xlabel('Índice del Punto')
plt.ylabel('Valor')
#plt.legend()

plt.subplot(1, 2, 2)
plt.plot(BTw_minus_e, label='BTw - e')
plt.title('Conjunto C')
plt.xlabel('Índice del Punto')
plt.ylabel('Valor')
#plt.legend()

plt.tight_layout()
plt.show()

# %%
w = x[:-1]  
beta = x[-1] 
A = B_mat
B = C_mat

# Calcula ATw - e y BTw - e
e_A = np.ones(A.shape[0])
ATw_minus_e = A.dot(w) - e_A * beta

e_B = np.ones(B.shape[0])
BTw_minus_e = B.dot(w) - e_B * beta

# Asegurémonos de que las dimensiones de ATw_minus_e y BTw_minus_e son adecuadas para graficar
# Por claridad, vamos a aplanar los arrays para garantizar que son 1D
ATw_minus_e = ATw_minus_e.flatten()
BTw_minus_e = BTw_minus_e.flatten()

# Graficación en una sola gráfica usando scatter
plt.figure(figsize=(10, 5))

# Aquí no necesitamos generar índices ya que scatter puede manejar los valores directamente
plt.scatter(np.arange(len(ATw_minus_e)), ATw_minus_e, color='blue', label='Conjunto B', alpha=0.7)
plt.scatter(np.arange(len(BTw_minus_e)) + len(ATw_minus_e), BTw_minus_e, color='red', label='Conjunto C', alpha=0.7)

plt.title('Comparación de Conjunto B y C respecto al Hiperplano')
plt.xlabel('Índice del Punto')
plt.ylabel('Valor (BTw - e, CTw - e)')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Visualización del conjunto

# %%
A = B_mat
B = C_mat

w = x[:-1]  
beta = x[-1] 


# Definir las combinaciones de características
combinaciones = [(0, 1), (0, 2), (0, 3), (1, 2), (1, 3), (2, 3)]

# Crear una figura y ejes para las subgráficas
fig, axes = plt.subplots(2, 3, figsize=(15, 10))
fig.suptitle('Comparación de Grupos B y C en diferentes combinaciones de características')

for i, (feat1, feat2) in enumerate(combinaciones):
    ax = axes[i//3, i%3]
    # Graficar los puntos de A y B para cada combinación de características
    ax.scatter(A[:, feat1], A[:, feat2], color='blue', label='Grupo B')
    ax.scatter(B[:, feat1], B[:, feat2], color='red', label='Grupo C')
    ax.set_xlabel(f'Característica {feat1+1}')
    ax.set_ylabel(f'Característica {feat2+1}')
    ax.legend()


plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
#Aplicamos PCA a 2 dimensiones.
features = ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']
x = iris.loc[:, features].values
y = iris.loc[:,['Species']].values
x = StandardScaler().fit_transform(x)

pca = PCA(n_components=2)
principalComponents = pca.fit_transform(x)
principalDf = pd.DataFrame(data = principalComponents, columns = ['PCA1', 'PCA2'])

finalDf = pd.concat([principalDf, iris[['Species']]], axis = 1)
df = finalDf

# Visualización
sns.set(style="whitegrid", palette="muted")
plt.figure(figsize=(10, 6), dpi=100)
sns.scatterplot(x='PCA1', y='PCA2', hue='Species', data=finalDf, palette="deep")
plt.title('2D PCA of Iris Dataset', fontsize=14)
plt.xlabel('Principal Component 1', fontsize=12)
plt.ylabel('Principal Component 2', fontsize=12)
plt.legend(title='Species', fontsize=10)
plt.show()

# %%
df.head()
# Out:
#        PCA1      PCA2      Species
# 0 -2.264542  0.505704  Iris-setosa
# 1 -2.086426 -0.655405  Iris-setosa
# 2 -2.367950 -0.318477  Iris-setosa
# 3 -2.304197 -0.575368  Iris-setosa
# 4 -2.388777  0.674767  Iris-setosa

# %%
# Conjunto A tiene a 'Iris-setosa'
conjunto_A = df[df['Species'] == 'Iris-setosa']

# Conjunto B tiene a 'Iris-virginica' y 'Iris-versicolor'
conjunto_B = df[(df['Species'] == 'Iris-virginica') | (iris['Species'] == 'Iris-versicolor')]

# %%
A_mat = conjunto_A[["PCA1", "PCA2"]].values
B_mat = conjunto_B[["PCA1", "PCA2"]].values

Vec_m1 = np.full((len(conjunto_A), 1), -1)
Vec_1 = np.full((len(conjunto_B), 1), 1)

concatenated_matrix_up = np.hstack((-A_mat, Vec_m1))
concatenated_matrix_down = np.hstack((B_mat, Vec_1))

F = np.vstack((concatenated_matrix_up, concatenated_matrix_down))

# Definiendo Q, c y d para el problema de programación cuadrática
Q = np.eye(F.shape[1])
c = np.full((F.shape[1], 1), 0)
d = np.full((F.shape[0], 1), 1)

# %%
(x, mu, z, iteraciones) = myqp_intpoint_modificado(Q, F, c, d)
# Out:
# Iteración: 1 | Norma de cnpo: 229.49413995659125
# Iteración: 2 | Norma de cnpo: 167.72510458216004
# Iteración: 3 | Norma de cnpo: 87.12310885417344
# Iteración: 4 | Norma de cnpo: 32.726469812937864
# Iteración: 5 | Norma de cnpo: 6.057645093437549
# Iteración: 6 | Norma de cnpo: 0.5312186267398757
# Iteración: 7 | Norma de cnpo: 0.2517241175897253
# Iteración: 8 | Norma de cnpo: 0.17827213300733333
# Iteración: 9 | Norma de cnpo: 0.15068279504822624
# Iteración: 10 | Norma de cnpo: 0.07941108848888428
# Iteración: 11 | Norma de cnpo: 0.04502927089417015
# Iteración: 12 | Norma de cnpo: 0.023661089402159084
# Iteración: 13 | Norma de cnpo: 0.01244764728197743
# Iteración: 14 | Norma de cnpo: 0.006543269769749762
# Iteración: 15 | Norma de cnpo: 0.003437654268119827
# Iteración: 16 | Norma de cnpo: 0.0018054607201246082
# Iteración: 17 | Norma de cnpo: 0.0009480604491684139
# Iteración: 18 | Norma de cnpo: 0.0004977854827326335
# Iteración: 19 | Norma de cnpo: 0.0002613522491174803
# Iteración: 20 | Norma de cnpo: 0.00013721403770955697
# Iteración: 21 | Norma de cnpo: 7.203850295287377e-05
# Iteración: 22 | Norma de cnpo: 3.7820526547613325e-05
# Iteración: 23 | Norma de cnpo: 1.9855862594382328e-05
# Iteración: 24 | Norma de cnpo: 1.0424351612631056e-05

# %%
x
# Out:
# array([[ 1.66346772],
#        [-0.44821844],
#        [ 1.07020995]])

# %%
w1 = x[0]
w2 = x[1]
e = x[2]

# Puntos para 'x1' (PCA1)
x1_values = np.linspace(-3, 3, 100)
# Calcular los valores correspondientes de 'x2' (PCA2) usando la fórmula del hiperplano
x2_values = (-w1 / w2) * x1_values - e / w2

# Graficar el hiperplano
plt.figure(figsize=(10, 6))
plt.plot(x1_values, x2_values, label='Hiperplano', color='red')

# Conjunto A: Iris-setosa
conjunto_A = df[df['Species'] == 'Iris-setosa']
x_pca1_A = conjunto_A['PCA1'].values
x_pca2_A = conjunto_A['PCA2'].values

# Conjunto B: Iris-virginica y Iris-versicolor
conjunto_B = df[(df['Species'] == 'Iris-virginica') | (df['Species'] == 'Iris-versicolor')]
x_pca1_B = conjunto_B['PCA1'].values
x_pca2_B = conjunto_B['PCA2'].values

plt.scatter(x_pca1_A, x_pca2_A, c='blue', label='Iris-setosa', alpha=0.6)
plt.scatter(x_pca1_B, x_pca2_B, c='green', label='Iris-virginica / Iris-versicolor', alpha=0.6)


plt.xlim(min(x_pca1_A.min(), x_pca1_B.min()) - 1, max(x_pca1_A.max(), x_pca1_B.max()) + 1)
plt.ylim(min(x_pca2_A.min(), x_pca2_B.min()) - 1, max(x_pca2_A.max(), x_pca2_B.max()) + 1)


# Añadir etiquetas y leyenda
plt.title('Grafico del Hiperplano en 2D para el conjunto de datos Iris')
plt.xlabel('PCA1')
plt.ylabel('PCA2')
plt.legend()
plt.grid(True)
plt.show()
